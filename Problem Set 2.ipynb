# %%
#Question 1:
a = 0
def b():
    global a
    a = c(a)
def c(a):
    return a + 2

b() 
# when we call the function b,then value of a is 0 and next line is a = c(a).
# Here it calling the function c and storing the value of a in a.
# And there is return statement in c function which is a+2.so a = c(a) = 0+2 = 2.
# So the value of a is 2.

b()
#Here we know the value of a is 2.
#So again next line call the function c and again a+2 = 2+2 = 4.
#So the value of a is 4.

b()
#Here we know the value of a is 4.
#So again next line call the function c and again a+2 = 4+2 = 6.
#So the value of a is 6.


print(a)
#Here we know the value of a is 6.
# Out:
# 6

# %%
#Question 2 :
def file_lenght(file_name):
    with open(file_name,'r') as file:
        content = file.read()
        print(len(content))

if __name__ == '__main__':
    file_name = input("Please enter your file name :")
    file_lenght(file_name)
# Out:
# Please enter your file name :helo.txt
# 25

# %%
#Question 3:
# Write a class named Marsupial that can be used as shown below:
# >>> m = Marsupial()
# >>> m.put_in_pouch('doll')
# >>> m.put_in_pouch('firetruck')
# >>> m.put_in_pouch('kitten')
# >>> m.pouch_contents()
# ['doll', 'firetruck', 'kitten']

# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the
# attributes of Marsupial and also:
# a. extends the Marsupial __init__ constructor to take, as input, the
# coordinates x and y of the Kangaroo object,
# b. supports method jump that takes number values dx and dy as input and
# movesthe kangaroo by dx units along the x-axis and by dy units along the yaxis, and
# c. overloads the __str__ operator so it behaves as shown below.

# >>> k = Kangaroo(0,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (0,0)
# >>> k.put_in_pouch('doll')
# >>> k.put_in_pouch('firetruck')
# >>> k.put_in_pouch('kitten')
# >>> k.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (3,0)


class Marsupial():
    def __init__(self):
        self.pouch = []

    def put_in_pouch(self, obj):
        self.pouch.append(obj)

    def pouch_contents(self):
        print(self.pouch)


class Kangaroo(Marsupial):
    def __init__(self, x, y):
        Marsupial.__init__(self)
        self.x = x
        self.y = y

    def jump(self, g, h):
        self.x += g
        self.y += h

    def __str__(self):
        return "I am a Kangaroo located at coordinates ({},{})".format(self.x, self.y)


k = Kangaroo(0, 0)
print(k)
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
k.pouch_contents()
k.jump(1, 0)
k.jump(1, 0)
k.jump(1, 0)
print(k)
# Out:
# I am a Kangaroo located at coordinates (0,0)
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (3,0)

# %%
#Question 4 :
def collatz(x):
    print(x)
    if x == 1:
        return

    elif x%2 == 0 :
        return collatz(int(x/2))
    else:
        return collatz(3*x+1)


if __name__ == "__main__":
    x = int(input("Please enter your number :"))
    collatz(x)
# Out:
# Please enter your number :10
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
#Question 5 :
def binary(n,st):
    if n == 0:
       return  str(n) + st
    elif n == 1:
       return str(n) + st
    else:
        nu = n%2
        st = str(nu) + st
        return binary(n//2,st)


if __name__ == "__main__":
    st = ""
    n = int(input("Please enter non-negative integer value :"))
    print(binary(n,st))
# Out:
# Please enter non-negative integer value :11
# 1011

# %%
#Question 6 :



import html.parser


class HeadingParser(html.parser.HTMLParser):

    def __init__(self):
        super().__init__()
        self.indent = 0

    def handle_starttag(self, tag, attrs):
        if tag == 'h1':
            self.indent = 0
        elif tag == 'h2':
            self.indent = 1
        elif tag == 'h3':
            self.indent = 2
        elif tag == 'h4':
            self.indent = 3
        elif tag == 'h5':
            self.indent = 4
        elif tag == 'h6':
            self.indent = 5

    def handle_data(self, data):
        print('\t' * self.indent + data)


parser = HeadingParser()


with open('Wc3.html', 'r') as f:
    parser.feed(f.read())
    parser.close()
    print('Done')
    f.close()

# %%
#Question 7 :
# Implement recursive function webdir() that takes as input: a URL (as a string) and
# non-negative integers depth and indent. Your function should visit every web
# page reachable from the starting URL web page in depth clicks or less, and print
# each web page's URL. As shown below, indentation, specified by indent, should
# be used to indicate the depth of a URL.
# >>>
# webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html'
# , 2, 0)
# http://reed.cs.depaul.edu/lperkovic/csc242/test1.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test2.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test4.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test3.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test4.html


import urllib.request


def webdir(url, depth, indent):
    if depth == 0:
        return
    try:
        response = urllib.request.urlopen(url)
        html = response.read()
        print(url)
        for line in html.decode().split('\n'):
            if 'href' in line:
                webdir(line.split('"')[1], depth - 1, indent + 1)
    except:
        return  # ignore errors


if __name__ == '__main__':

    ans = webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test4.html', 2, 0)
    print(ans)

    # webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html', 2, 0)
    # http://reed.cs.depaul.edu/lperkovic/csc242/test1.html
    # http://reed.cs.depaul.edu/lperkovic/csc242/test2.html
    # http://reed.cs.depaul.edu/lperkovic/csc242/test4.html
# Out:
# None

# %%
#Question 8 :
# suppose that all the data is stored in a database in form of table and columns.
# And database name is weather.
# And tables are:
# 1. City
# 2. Country
# 3. Season
# 4. Temperature(C)
# 5. Rainfall(mm)


# SQL queries:

# a) All the temperature data.
("SELECT * FROM weather")

# b) All the cities, but without repetition.
("SELECT DISTINCT city FROM weather")


# c) All the records for India.
("SELECT * FROM weather WHERE country = 'India'")


# d) All the Fall records.
("SELECT * FROM weather WHERE season = 'Fall'")


# e) The city, country, and season for which the average rainfall is between 200
# and 400 millimeters.
("SELECT city, country, season FROM weather WHERE rainfall BETWEEN 200 AND 400")


# f) The city and country for which the average Fall temperature is above 20
# degrees, in increasing temperature order.
("SELECT city, country FROM weather WHERE temperature > 20 AND season = 'Fall' ORDER BY temperature")


# g) The total annual rainfall for Cairo.
("SELECT SUM(rainfall) FROM weather WHERE city = 'Cairo'")


# h) The total rainfall for each season.
("SELECT SUM(rainfall) FROM weather WHERE DISTINCT season")

# %%
#Question 9 :



words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the','lazy', 'dog']


#  ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE','LAZY', 'DOG']

upperCase = [word.upper() for word in words]
print(upperCase)

# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the','lazy', 'dog']

lowerCase = [word.lower() for word in words]
print(lowerCase)

# c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list
# words).

countWord = [len(word) for word in words]
print((countWord))


# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN',
# 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5],
# ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy',
# 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list
# words, where each list contains the word in uppercase and lowercase and the
# length of the word.)

arrayInsideArray = [[word.upper(),word.lower(),len(word)] for word in words]
print((arrayInsideArray))


# e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog'] (the list of words in list words containing 4 or more
# characters.)

moreThenFour = [word for word in words if len(word)>=4]

print(moreThenFour)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# ['quick', 'brown', 'jumps', 'over', 'lazy']
